# %% [markdown]
# <a href="https://colab.research.google.com/github/vonnkee13/SortingArray/blob/main/Youtube_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
import time

# %%
API_KEY = 'AIzaSyCdXwOJWGgSYKrW9KTdo_XKKw5tZlfaWfE'
CHANNEL_ID = 'UCOoCLoWMQ4G_X5vIhR6Pzog'

# %%
#make API call
pageToken = ''
url = 'https://www.googleapis.com/youtube/v3/search?key='+API_KEY+'&channelId='+CHANNEL_ID+'&part=snippet,id&order=date&maxResults=1000'+pageToken
response = requests.get(url).json()

# %%
video_id=response['items'][0]['id']['videoId']

# %%
response['items'][0]['snippet']['title']
# Out:
# '5 Shihtzu Puppies 🐾'

# %%
upload_date=response['items'][0]['snippet']['publishedAt'].split('T')[0]

# %%
for video in response['items']:
  if video['id']['kind'] == 'youtube#video':
    video_id = video['id']['videoId']
    upload_date = video['snippet']['publishedAt'].split('T')[0]
    video_title = video['snippet']['title']

    print(video_id)
    print(video_title)
    print(upload_date)
# Out:
# h2TUum77eRk
# 5 Shihtzu Puppies 🐾
# 2021-08-01
# cysLBFfSM1U
# 8 months 5 Shihtzu Puppies
# 2021-08-01
# 3LoklURSAsw
# Tweedle ❤️
# 2021-05-11
# iEt2uaPHskM
# 5 Shihtzu Puppies 🐾
# 2021-05-08
# 1Fm6s3nEgQI
# 5 Shihtzu puppies 🐾❤️
# 2021-04-10
# TNQdyvSo3zI
# 5 Shihtzu Puppies 🐾 | 5 months old part 2
# 2021-04-08
# QzCOCzv8Q-k
# 5 Shihtzu Puppies 🐾 | 5 months old 🙂
# 2021-04-08
# IOe5lOXEJFU
# Shihtzu watching Teletubbies part 2 | Tweedle the mama dog
# 2021-04-07
# PtZKq7DCJtc
# Shih tzu watching Teletubbies 😁😂 | Tweedle the Mama dog
# 2021-04-07
# xZP2TRJW-Lo
# Mama Dog (Tweedle) watching Billie Eilish
# 2021-03-17
# wG0GPQHoY8A
# Sleeping PAWtatoes ❤️😁
# 2021-03-11
# YpWD9ZynWn4
# They Grew Up so Fast 😁🥳
# 2021-02-28
# CNF42Px3EsI
# PAWtato 🐶😅
# 2021-02-25
# 6DKhp057g3I
# 5 Shihtzu Puppies 🐾 | Bagong Ligo 🧽😎🐶😁
# 2021-02-25
# cmVRniJ3XCk
# Happy 3rd Birthday Tweedle 🎉 | ft. Boiled Chicken | Tweedle the Mama/Nanay Shitzu Dog |
# 2021-02-03
# jrXxYVP6UH0
# ...

# %%
url_video_stats = 'https://www.googleapis.com/youtube/v3/videos?id='+video_id+'&part=statistics&key='+API_KEY
response_video_stats = requests.get(url_video_stats).json()

# %%
response_video_stats
# Out:
# {'etag': 'Ti5-FBq1CiixysJfjhxo5ovJres',
#  'items': [{'etag': '_20d8dxzXCLgOxCGmYDSY_PcyPg',
#    'id': 'Atl8ZoDmsuY',
#    'kind': 'youtube#video',
#    'statistics': {'commentCount': '1',
#     'favoriteCount': '0',
#     'likeCount': '93',
#     'viewCount': '3144'}}],
#  'kind': 'youtube#videoListResponse',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 1}}

# %%
for video in response['items']:
  if video['id']['kind'] == 'youtube#video':
    video_id = video['id']['videoId']
    upload_date = video['snippet']['publishedAt'].split('T')[0]
    video_title = video['snippet']['title']

    print(video_id)
    print(video_title)
    print(upload_date)

    #collecting views, likes, dislikes
    url_video_stats = 'https://www.googleapis.com/youtube/v3/videos?id='+video_id+'&part=statistics&key='+API_KEY
    response_video_stats = requests.get(url_video_stats).json()

    view_count = response_video_stats['items'][0]['statistics']['viewCount']
    like_count = response_video_stats['items'][0]['statistics']['likeCount']
    comment_count = response_video_stats['items'][0]['statistics']['commentCount']
# Out:
# h2TUum77eRk
# 5 Shihtzu Puppies 🐾
# 2021-08-01
# 978
# 38
# 3
# cysLBFfSM1U
# 8 months 5 Shihtzu Puppies
# 2021-08-01
# 656
# 18
# 0
# 3LoklURSAsw
# Tweedle ❤️
# 2021-05-11
# 4329
# 206
# 4
# iEt2uaPHskM
# 5 Shihtzu Puppies 🐾
# 2021-05-08
# 887
# 42
# 2
# 1Fm6s3nEgQI
# 5 Shihtzu puppies 🐾❤️
# 2021-04-10
# 886
# 56
# 6
# TNQdyvSo3zI
# 5 Shihtzu Puppies 🐾 | 5 months old part 2
# 2021-04-08
# 650
# 33
# 1
# QzCOCzv8Q-k
# 5 Shihtzu Puppies 🐾 | 5 months old 🙂
# 2021-04-08
# 778
# 33
# 1
# IOe5lOXEJFU
# Shihtzu watching Teletubbies part 2 | Tweedle the mama dog
# 2021-04-07
# 136
# 13
# 0
# PtZKq7DCJtc
# Shih tzu watching Teletubbies 😁😂 | Tweedle the Mama dog
# 2021-04-07
# 161
# 15
# 2
# xZP2TRJW-Lo
# Mama Dog (Tweedle) watching Billie Eilish
# 2021-03-17
# 699
# 53
# 0
# wG0GPQHoY8A
# Sleeping PAWtatoes ❤️😁
# 2021-03-11
# 477
# 27
# 1
# YpWD9ZynWn4
# They Grew Up so Fast 😁🥳
# 2021-02-28
# 717
# 27
# 1
# CNF42Px3EsI
# PAWtato 🐶😅
# 2021-02-25
# 1563
# 59
# 2
# 6DKhp057g3I
# ...

# %%
#build our dataframe

column_names = ['video_id','upload_date','video_title','view_count','like_count','comment_count']
df = pd.DataFrame(columns=column_names)

# %%
df
# Out:
# Empty DataFrame
# Columns: [video_id, upload_date, video_title, view_count, like_count, comment_count]
# Index: []

# %%
for video in response['items']:
  if video['id']['kind'] == 'youtube#video':
    video_id = video['id']['videoId']
    upload_date = video['snippet']['publishedAt'].split('T')[0]
    video_title = video['snippet']['title']

    #collecting views, likes, dislikes
    url_video_stats = 'https://www.googleapis.com/youtube/v3/videos?id='+video_id+'&part=statistics&key='+API_KEY
    response_video_stats = requests.get(url_video_stats).json()

    view_count = response_video_stats['items'][0]['statistics']['viewCount']
    like_count = response_video_stats['items'][0]['statistics']['likeCount']
    comment_count = response_video_stats['items'][0]['statistics']['commentCount']

    #save data in pandas dataframe

    df = df.append({
        'video_id': video_id, 'upload_date': upload_date, 'video_title': video_title, 'view_count':view_count, 'like_count':like_count, 'comment_count':comment_count
    },ignore_index=True)

# %%
df
# Out:
#        video_id upload_date  \
# 0   h2TUum77eRk  2021-08-01
# 1   cysLBFfSM1U  2021-08-01
# 2   3LoklURSAsw  2021-05-11
# 3   iEt2uaPHskM  2021-05-08
# 4   1Fm6s3nEgQI  2021-04-10
# 5   TNQdyvSo3zI  2021-04-08
# 6   QzCOCzv8Q-k  2021-04-08
# 7   IOe5lOXEJFU  2021-04-07
# 8   PtZKq7DCJtc  2021-04-07
# 9   xZP2TRJW-Lo  2021-03-17
# 10  wG0GPQHoY8A  2021-03-11
# 11  YpWD9ZynWn4  2021-02-28
# 12  CNF42Px3EsI  2021-02-25
# 13  6DKhp057g3I  2021-02-25
# 14  cmVRniJ3XCk  2021-02-03
# 15  jrXxYVP6UH0  2021-02-03
# 16  Ztti6dnZXPk  2021-02-03
# 17  6Gq6wWb7GU4  2021-01-28
# 18  N7mV8bG0Zfo  2021-01-22
# 19  114hdHiGI5Q  2021-01-20
# 20  t9O35wK5_nA  2021-01-20
# 21  SphRcIsWMLU  2021-01-20
# 22  WHSjAd_titk  2021-01-18
# 23  XDM6odwAj1k  2021-01-17
# 24  uzUbZpndzPM  2021-01-15
# 25  WpPZDUPyt5E  2021-01-15
# 26  vyuIOw84KsI  2021-01-15
# 27  tIhQyFUO1R8  2021-01-14
# 28  mdllH634jiU  2021-01-14
# 29  r2ZlOEYohRA  2021-01-10
# 30  9xiaBnLBePs  2021-01-08
# 31  4RMi8hamiQA  2021-01-07
# ...
